# %% [markdown]
# # Demographic Table One
# ### Author: Divya Veerapaneni MS4, Ong Lab
# ### Description: This ipynb creates the table one demographics table from an input excel file
# ### Input:
# #### 1. Consolidated_Study_Cohort_Traits.xlsx - patient data
# #### 2. Formatted csv file with data for displaying via pandas
# ### Output: demographic table one, an excel sheet

# %%
#import statements
import tableone
import pandas as pd
import HelperMethods
import dataframe_image as dfi

#input files
file_path = '/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Data/Intermediate Datasets/'
ground_truth = pd.read_excel('/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Data/Consolidated_Study_Cohort_Traits.xlsx')
ground_truth.Discharge_Disposition = ground_truth.Discharge_Disposition.replace({"Skilled Nursing Facility":"Rehab Facility"})
print(ground_truth.columns)
# Out:
# /Users/divs/opt/anaconda3/lib/python3.9/site-packages/seaborn/rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /Users/divs/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# Index(['MRN', 'ID', 'Consolidate', 'Crani_Surgery', 'Surgery details', 'Bolt',
#        'EVD', 'Marshall', 'Rotterdam', 'Time_to_most_severe_CT',
#        'Discharge_Disposition', 'Unfavorable_Outcome', 'Deceased',
#        'Orientedx3', 'Awake_Alert', 'HgbA1c', 'Mechanism_Injury', 'PRES_DT',
#        'ADMIT_DT', 'DISCH_DT', 'tbi_severity', 'AGE', 'SEX', 'RACE',
#        'RACE_Black', 'GCS', 'lower_npi', 'average_npi', 'npi_diff',
#        'size_diff', 'n_obs', 'time_to_first_obs', 'lower_npi_0_removed',
# ...

# %% [markdown]
# # Full Cohort

# %%
# columns to summarize
columns = [ 'tbi_severity', 'AGE', 'SEX', 'RACE', 'GCS', 'Mechanism_Injury','Crani_Surgery', 'Bolt','EVD', 'Marshall', 'Rotterdam', \
           'Time_to_most_severe_CT', 'n_obs',\
  'time_to_first_obs', 'average_npi', 'lower_npi', 'npi_diff', 'size_diff', 'average_npi_0_removed', 'lower_npi_0_removed', \
 'any_incidence', 'poor_npi_incidence','npi_diff_incidence', 'size_diff_incidence', 'uni_any_incidence', 'uni_stage_incidence',\
       'stage1u_incidence', 'stage2u_incidence', 'stage3u_incidence','stage4u_incidence', \
       'bi_incidence', 'stage1b_incidence','stage2b_incidence', 'stage3b_incidence', \
        'npi_diff_size_diff_incidence', 'size_diff_poor_npi_incidence',\
  'any_burden', 'poor_npi_burden', 'npi_diff_burden', 'size_diff_burden','uni_any_burden',\
      'uni_stage_burden', 'stage1u_burden', 'stage2u_burden', 'stage3u_burden', 'stage4u_burden', \
        'bi_burden', 'stage1b_burden', 'stage2b_burden','stage3b_burden',\
      'npi_diff_size_diff_burden','size_diff_poor_npi_burden',\
'Discharge_Disposition','Unfavorable_Outcome', 'Deceased', 'Orientedx3', 'Awake_Alert'\
]

# columns containing categorical variables
categorical = ['SEX', 'RACE', 'Mechanism_Injury', 'Discharge_Disposition', 'Orientedx3', 'Awake_Alert', \
               'Deceased', 'Unfavorable_Outcome', 'Crani_Surgery', 'Bolt', 'EVD',\
                'any_incidence', 'poor_npi_incidence','npi_diff_incidence', 'size_diff_incidence', 'uni_any_incidence',\
       'uni_stage_incidence', 'stage1u_incidence', 'stage2u_incidence', 'stage3u_incidence','stage4u_incidence', \
       'bi_incidence', 'stage1b_incidence','stage2b_incidence', 'stage3b_incidence', \
        'npi_diff_size_diff_incidence', 'size_diff_poor_npi_incidence']

# non-normal variables
nonnormal = ['AGE', 'GCS', \
             'n_obs','time_to_first_obs', 'average_npi', 'lower_npi', 'npi_diff', 'size_diff', 'average_npi_0_removed', 'lower_npi_0_removed',\
              'any_burden', 'poor_npi_burden', 'npi_diff_burden', 'size_diff_burden','uni_any_burden',\
      'uni_stage_burden', 'stage1u_burden', 'stage2u_burden', 'stage3u_burden', 'stage4u_burden', \
        'bi_burden', 'stage1b_burden', 'stage2b_burden','stage3b_burden',\
      'npi_diff_size_diff_burden','size_diff_poor_npi_burden']

# limit the binary variable "death" to a single row
limit = {"SEX": 2, "Mechanism_Injury":2, 'Orientedx3':1, 'Awake_Alert':1, 'Crani_Surgery':2, 'Bolt':2, 'EVD':2, 'Unfavorable_Outcome':2}
limit_vars = ['stage1u_incidence',\
'stage2u_incidence', 'stage3u_incidence', 'stage3u_v2_incidence', 'stage4u_incidence', 'stage1b_incidence',\
'stage2b_incidence', 'uni_incidence', 'bi_incidence', 'any_incidence', 'npi_diff_incidence', 'size_diff_incidence']

# set decimal places for age to 0
decimals = dict()
for c in columns:
    decimals[c] = 0
decimals.pop('tbi_severity')
for col in ['average_npi', 'lower_npi', 'npi_diff', 'size_diff', 'average_npi_0_removed', 'lower_npi_0_removed',  'Marshall', 'Rotterdam']:
  decimals[col] = 1

# optionally, a categorical variable for stratification
groupby = ['tbi_severity']

#create table_one using TableOne package
table1 = tableone.TableOne(ground_truth, columns=columns, categorical=categorical, missing=False, groupby=groupby,
                  nonnormal=nonnormal, label_suffix=True, limit=limit,
                  decimals=decimals,  pval=True)

table1
# Out:
#                                                                  Grouped by tbi_severity
#                                                                                  Overall           Mild       Moderate         Severe P-Value
# n                                                                                    136             49             20             67
# AGE, median [Q1,Q3]                                                           58 [38,71]     68 [60,80]     54 [45,75]     48 [28,64]  <0.001
# SEX, n (%)                                M                                      96 (71)        34 (69)        10 (50)        52 (78)   0.058
#                                           F                                      40 (29)        15 (31)        10 (50)        15 (22)
# RACE, n (%)                               Black                                  28 (21)         8 (16)         4 (20)        16 (24)   0.109
# ...

# %%
# Save to Excel
fn1 = 'tableone_11-15.xlsx'
#table1.to_excel('/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/' +fn1)

# %% [markdown]
# # Abnormal Pupil Phenotype Cohort

# %%
# patients with at least one pupil abnormality
abn_pts = ground_truth[ground_truth.any_incidence == 1]
abn_pts = abn_pts[['tbi_severity',  'any_burden', 'poor_npi_burden', 'npi_diff_burden', 'size_diff_burden','uni_any_burden',\
      'uni_stage_burden', 'stage1u_burden', 'stage2u_burden', 'stage3u_burden', 'stage4u_burden', \
        'bi_burden', 'stage1b_burden', 'stage2b_burden','stage3b_burden',\
      'npi_diff_size_diff_burden','size_diff_poor_npi_burden']]
abn_pts
# Out:
#     tbi_severity  any_burden  poor_npi_burden  npi_diff_burden  \
# 2         Severe   83.116883        41.558442        76.623377
# 3           Mild   89.285714         0.000000        82.142857
# 4           Mild   14.814815         3.703704         0.000000
# 5         Severe    4.411765         0.000000         4.411765
# 6         Severe   26.666667         0.000000         3.333333
# ..           ...         ...              ...              ...
# 130         Mild   65.217391        39.130435        30.434783
# 131         Mild   16.666667         8.333333        16.666667
# 133       Severe    5.000000         0.000000         5.000000
# 134       Severe  100.000000       100.000000        14.285714
# 135         Mild    8.333333         0.000000         0.000000
#
#      size_diff_burden  uni_any_burden  uni_stage_burden  stage1u_burden  \
# 2           20.779221       76.623377         31.168831       31.168831
# ...

# %%
# columns to summarize
columns = ['tbi_severity', 'any_burden', 'poor_npi_burden', 'npi_diff_burden', 'size_diff_burden','uni_any_burden',\
      'uni_stage_burden', 'stage1u_burden', 'stage2u_burden', 'stage3u_burden', 'stage4u_burden', \
        'bi_burden', 'stage1b_burden', 'stage2b_burden','stage3b_burden',\
      'npi_diff_size_diff_burden','size_diff_poor_npi_burden']

# non-normal variables
nonnormal = [  'any_burden', 'poor_npi_burden', 'npi_diff_burden', 'size_diff_burden','uni_any_burden',\
      'uni_stage_burden', 'stage1u_burden', 'stage2u_burden', 'stage3u_burden', 'stage4u_burden', \
        'bi_burden', 'stage1b_burden', 'stage2b_burden','stage3b_burden',\
      'npi_diff_size_diff_burden','size_diff_poor_npi_burden']

# set decimal places for age to 0
decimals = 0

# optionally, a categorical variable for stratification
groupby = ['tbi_severity']

table2 = tableone.TableOne(abn_pts, columns=columns, groupby=groupby, nonnormal=nonnormal,  decimals = decimals, missing=False, label_suffix=True,pval=True)
table2
# Out:
#                                            Grouped by tbi_severity
#                                                            Overall       Mild    Moderate      Severe P-Value
# n                                                              102         30          13          59
# any_burden, median [Q1,Q3]                              19 [10,44]  17 [6,24]  30 [12,46]  20 [11,56]   0.061
# poor_npi_burden, median [Q1,Q3]                           3 [0,16]    0 [0,5]     0 [0,6]    6 [0,36]   0.004
# npi_diff_burden, median [Q1,Q3]                           6 [0,17]   0 [0,17]    4 [4,13]    8 [3,17]   0.074
# size_diff_burden, median [Q1,Q3]                          7 [2,21]   8 [3,14]   20 [2,33]    6 [0,22]   0.535
# uni_any_burden, median [Q1,Q3]                           17 [7,30]  17 [6,24]  30 [12,46]   15 [8,32]   0.160
# uni_stage_burden, median [Q1,Q3]                           0 [0,6]    0 [0,4]     0 [0,4]     2 [0,7]   0.233
# ...

# %%
# Save to Excel
fn1 = 'tableone_abn_pupils_9-13.xlsx'
# table2.to_excel('/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/' +fn1)

# %% [markdown]
# # Display Demographic Table in Pandas

# %%
#read input files
file_path = '/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/Table CSV Inputs/'
df = pd.read_csv(file_path + 'Table1_NCS_input.csv')

#format pandas display output
s = df.style.format(na_rep='').hide_index()\
    .hide_columns()\
    .set_properties(**{'white-space': 'pre'})\
    .set_properties(subset=[ 'Unnamed: 1', 'Severity of Traumatic Brain Injury', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], **{'text-align': 'center'})\
    .set_properties(subset=[ 'Unnamed: 0'], **{'text-align': 'left'})\
    .set_properties(subset=[ 'Unnamed: 0'], **{'font-weight': 'bold'})\
    .set_properties(subset=pd.IndexSlice[df.index[df.index == 0],:], **{'font-weight': 'bold'})

s = s.set_caption("[1] Chi-squared tests for the following variables may be invalid due to the low number\
                   of observations: race, type of injury, decompressive surgery, icp monitor, EVD, discharge disposition, \
                  stage1u_incidence, stage2u_incidence,stage3u_incidence, stage1b_incidence, unilateral and bilateral incidence  <br> \
                  [2] mean NPi is defined as mean NPi across both eyes")\
 .set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: bottom; font-size:1em; text-align:left'}], overwrite=False)

#dfi.export(s,"/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/newest_table1.png")
s
# Out:
# <style type="text/css">
# #T_e1729 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_e1729_row0_col0 {
#   white-space: pre;
#   text-align: left;
#   font-weight: bold;
#   font-weight: bold;
# }
# #T_e1729_row0_col1, #T_e1729_row0_col2, #T_e1729_row0_col3, #T_e1729_row0_col4, #T_e1729_row0_col5 {
#   white-space: pre;
#   text-align: center;
#   font-weight: bold;
# }
# ...

# %%
#read input files
file_path = '/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/Table CSV Inputs/'
df = pd.read_csv('/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/Table_Multivariable_results.csv')
df =df.replace({0: '<0.001'})

#format pandas display output
s = df.style.format(na_rep='').hide_index()\
    .hide_columns()\
    .set_properties(**{'white-space': 'pre'})\
    .set_properties(subset=['Multivariable Model of Unfavorable Outcome and Pupil Metrics'], **{'text-align': 'left'})\
    .set_properties(subset=['Unfavorable Outcome', 'Unnamed: 2', 'Unnamed: 3', 'Deceased',
       'Unnamed: 5', 'Unnamed: 6', 'Oriented x 3', 'Unnamed: 8', 'Unnamed: 9',
       'Awake or alert', 'Unnamed: 11', 'Unnamed: 12'], **{'text-align': 'center'})\
    .set_properties(subset=pd.IndexSlice[df.index[df.index == 0],:], **{'font-weight': 'bold'}) \
.set_properties(subset=pd.IndexSlice[df.index[df.index == 9],:], **{'font-weight': 'bold'})\
.set_properties(subset=pd.IndexSlice[df.index[df.index == 23],:], **{'font-weight': 'bold'})\
.set_properties(subset=pd.IndexSlice[df.index[df.index == 37],:], **{'font-weight': 'bold'})

# dfi.export(s,"/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/multivariable_abn_pts.png")

s
# Out:
# <style type="text/css">
# #T_8bc78 .row9 {
#   border-bottom: 3px solid green;
# }
# #T_8bc78_row0_col0, #T_8bc78_row9_col0, #T_8bc78_row23_col0, #T_8bc78_row37_col0 {
#   white-space: pre;
#   text-align: left;
#   font-weight: bold;
# }
# ...

# %%
#read input files
file_path = '/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/Table CSV Inputs/'
df = pd.read_csv(file_path + 'new_Multivariable_Table_input.csv')
df['95% Cl'] = df['95% Cl'].str.replace(r'\'', '')
df.rename({"Unnamed: 0":" "}, axis="columns", inplace=True)
print(df.columns)

#format pandas display output
s = df.style.format({'Beta': "{:.2f}"}, precision=2,na_rep='').hide_index()\
    .set_properties(**{'white-space': 'pre'})\
    .set_properties(subset=[ ' '], **{'text-align': 'left'})\
    .set_properties(subset=[ ' '], **{'font-weight': 'bold'})\
    .set_properties(subset=pd.IndexSlice[df.index[df.index == 0],:], **{'font-weight': 'bold'})\
    .set_properties(subset=[ 'OR', '95% Cl', 'p-value'], **{'text-align': 'center'})\
    .set_caption("[1] Multivariable analysis using logistic regression model adjusting for age, black race, tbi severity, blunt vs. penetrating wound, and Rotterdam CT score <br> \
                  [2] ")\
    .set_table_styles([{'selector': 'caption','props': 'caption-side: bottom; font-size:1em; text-align:left'}], overwrite=False)

#dfi.export(s,"/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/newest_multivariable_table.png")
s
# Out:
# Index([' ', 'OR', '95% Cl', 'p-value'], dtype='object')
# <style type="text/css">
# #T_60427 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_60427_row0_col0 {
#   white-space: pre;
#   text-align: left;
#   font-weight: bold;
#   font-weight: bold;
# }
# #T_60427_row0_col1, #T_60427_row0_col2, #T_60427_row0_col3 {
#   white-space: pre;
#   font-weight: bold;
#   text-align: center;
# }
# ...

# %%
#read input files
file_path = '/Users/divs/Box/1-BMC Smartguards/10-Processing and Visualization/8-TBI Pupillometry/Manuscripts/2-Tables/'
df = pd.read_csv(file_path + 'new_Cox_univariate_input.csv')
df['95% Cl'] = df['95% Cl'].str.replace(r'\'', '')
df.rename({"Unnamed: 0":" "}, axis="columns", inplace=True)
print(df.columns)

#format pandas display output
s = df.style.format(na_rep='').hide_index()\
    .set_properties(**{'white-space': 'pre'})\
    .set_properties(subset=[ ' '], **{'text-align': 'left'})\
    .set_properties(subset=[ ' '], **{'font-weight': 'bold'})\
    .set_properties(subset=pd.IndexSlice[df.index[df.index == 0],:], **{'font-weight': 'bold'})\
    .set_properties(subset=[ 'HR', '95% Cl', 'p-value'], **{'text-align': 'center'})\
    .set_caption("[1] Univariate analysis using cox model to predict survival in first 7 days after admission <br> \
                  [2] HR is hazards ratio <br> \
                  [3] p value calculated using log rank test <br>\
                  [3] mean NPi is defined as mean NPi across both eyes")\
    .set_table_styles([{'selector': 'caption','props': 'caption-side: bottom; font-size:1em;text-align:left'}], overwrite=False)

# dfi.export(s,file_path + "newest_cox_univariate_averaged_table.png")
s
# Out:
# Index([' ', 'HR', '95% Cl', 'p-value'], dtype='object')
# <style type="text/css">
# #T_13637 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_13637_row0_col0 {
#   white-space: pre;
#   text-align: left;
#   font-weight: bold;
#   font-weight: bold;
# }
# #T_13637_row0_col1, #T_13637_row0_col2, #T_13637_row0_col3 {
#   white-space: pre;
#   font-weight: bold;
#   text-align: center;
# }
# #T_13637_row1_col0, #T_13637_row2_col0, #T_13637_row3_col0, #T_13637_row4_col0, #T_13637_row5_col0, #T_13637_row6_col0, #T_13637_row7_col0, #T_13637_row8_col0, #T_13637_row9_col0, #T_13637_row10_col0 {
#   white-space: pre;
#   text-align: left;
#   font-weight: bold;
# }
# ...
